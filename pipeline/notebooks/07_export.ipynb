# %% [markdown]
# # 💾 Notebook 07: Data Serialization & Web Export
# **Space-Based Economic Intelligence Thesis**
#
# This notebook demonstrates how to package and write geospatial anomalies to standard GeoJSON and flat JSON formats.

# %% [markdown]
# ### Load Exporters

# %%
from pipeline.src.exporter import GeospatialExporter
print("Exporter classes initialized.")

# %% [markdown]
# ### Export Sample Coordinates
# Serialize mock coordinate dictionaries into static JSON web caches.

# %%
exporter = GeospatialExporter()
sample_anomalies = [
    {
        "id": "anomaly_test_1",
        "type": "Test Anomaly",
        "region": "Test Region",
        "coordinates": [0.0, 0.0],
        "confidence": 0.99,
        "date": "2026-06-27",
        "spectral_profile": { "ndvi": 0.0, "ndwi": 0.0, "bsi": 0.0 },
        "details": "Test details",
        "verification": { "method": "Manual check", "ground_truth": "None", "status": "Testing" }
    }
]

exporter.export_anomalies_json(sample_anomalies, filename="test_anomalies.json")
print("Serialized test data successfully exported.")
