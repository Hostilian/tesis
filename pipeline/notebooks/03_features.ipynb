# %% [markdown]
# # 🧪 Notebook 03: Feature Extraction & Spectral Indices
# **Space-Based Economic Intelligence Thesis**
#
# This notebook demonstrates how to compute multi-spectral indices (NDVI, NDWI, BSI) to construct the feature matrix for anomaly detection.

# %% [markdown]
# ### Load Index Equations

# %%
import numpy as np
from pipeline.src.utils import calculate_ndvi, calculate_ndwi, calculate_bsi
print("Formulas imported from source scripts.")

# %% [markdown]
# ### Run Calculation on Simulated Bands

# %%
blue = np.random.uniform(0.01, 0.1, (5, 5))
red = np.random.uniform(0.02, 0.15, (5, 5))
green = np.random.uniform(0.02, 0.12, (5, 5))
nir = np.random.uniform(0.20, 0.60, (5, 5))
swir1 = np.random.uniform(0.05, 0.40, (5, 5))

ndvi = calculate_ndvi(nir, red)
bsi = calculate_bsi(swir1, red, nir, blue)

print("NDVI Matrix Mean:", np.mean(ndvi))
print("BSI Matrix Mean:", np.mean(bsi))
